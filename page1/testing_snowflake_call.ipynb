# %%
import os
from dotenv import load_dotenv
import pandas as pd
import snowflake.connector

load_dotenv()

conn = snowflake.connector.connect(
    account=os.getenv("SNOWFLAKE_ACCOUNT"),
    user=os.getenv("SNOWFLAKE_USER"),
    password=os.getenv("SNOWFLAKE_PASSWORD"),
    role=os.getenv("SNOWFLAKE_ROLE"),
    warehouse=os.getenv("SNOWFLAKE_WAREHOUSE"),
    database=os.getenv("SNOWFLAKE_DATABASE"),
    schema=os.getenv("SNOWFLAKE_SCHEMA"),
    # authenticator="externalbrowser",  # <- for SSO
    # private_key=...,                  # <- for key-pair auth
)

# Simple test query: swap table for what you actually need
sql = """
SELECT *
FROM SNACKLASH2.RAW.RSS_ARTICLES         -- your known table from past chats
ORDER BY PULLED_AT DESC
"""

df = pd.read_sql(sql, conn)
conn.close()

df.head(3)
# Out:
# /tmp/ipykernel_65350/122493978.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)
#                                                  URL  \
# 0  https://soundhealthandlastingwealth.com/chriss...
# 1  https://www.bbc.com/news/videos/cvgrj408l2qo?a...
# 2  https://www.bbc.com/news/articles/cre5xp83394o...
#
#                                                 GUID  GUID_IS_PERMALINK  \
# 0  https://soundhealthandlastingwealth.com/?p=244...              False
# 1     https://www.bbc.com/news/videos/cvgrj408l2qo#9              False
# 2   https://www.bbc.com/news/articles/cre5xp83394o#0              False
#
#                                                TITLE  \
# 0  Chrissy Teigen’s Emotional Weight Loss Journey...
# 1  Are chia seeds and other fibre 'hacks' good fo...
# 2  How weight-loss injections are turning obesity...
#
#                                              SUMMARY  \
# 0  <p>Chrissy Teigen took Ozempic to lose weight ...
# 1  Obesity and nutritional epidemiologist Dr Deir...
# 2  With claims of a 'two-tier system', could it b...
#
#                                         CONTENT_HTML  \
# 0  <ul>\n<li><strong><em>Chrissy Teigen took Ozem...
# 1                                               None
# 2                                               None
#
#                                         CONTENT_TEXT AUTHOR_NAME AUTHOR_EMAIL  \
# 0  <p>Chrissy Teigen took Ozempic to lose weight ...       shalw         None
# 1  Obesity and nutritional epidemiologist Dr Deir...        None         None
# 2  With claims of a 'two-tier system', could it b...        None         None
#
#   AUTHOR_URI  ...                                          IMAGE_URL  \
# 0       None  ...                                               None
# 1       None  ...  https://ichef.bbci.co.uk/ace/standard/240/cpsp...
# 2       None  ...  https://ichef.bbci.co.uk/ace/standard/240/cpsp...
#
#          SOURCE_NAME SOURCE_FEED_TITLE SOURCE_FEED_URL  \
# 0  Sound Health Blog              None            None
# 1       BBC - Health              None            None
# 2       BBC - Health              None            None
#
#                   PUBLISHED_AT_RAW UPDATED_AT_RAW  \
# 0  Mon, 22 Sep 2025 14:05:34 +0000           None
# 1    Wed, 24 Sep 2025 14:17:29 GMT           None
# 2    Mon, 29 Sep 2025 07:02:26 GMT           None
#
#                          PULLED_AT    MATCHING_RULE_IDS MATCHING_TERMS  \
# 0 2025-09-30 00:14:10.698680+00:00  [\n  501,\n  402\n]             []
# 1 2025-09-30 00:14:10.698680+00:00          [\n  402\n]             []
# 2 2025-09-30 00:14:10.698680+00:00          [\n  402\n]             []
#
#                                              RAW_XML
# 0  <item xmlns:dc="http://purl.org/dc/elements/1....
# 1  <item xmlns:ns0="http://search.yahoo.com/mrss/...
# 2  <item xmlns:ns0="http://search.yahoo.com/mrss/...
#
# [3 rows x 24 columns]

# %%
import os, json, base64
import streamlit as st
import pandas as pd
import boto3
import snowflake.connector
from botocore.exceptions import ClientError

SECRET_NAME = "snowflake-ec2-streamlit_connect"
REGION_NAME = "us-east-1"

# ---------- Secrets ----------
@st.cache_resource(show_spinner=False)
def get_secret_dict() -> dict:
    """Fetch and parse the JSON secret from AWS Secrets Manager."""
    try:
        sm = boto3.client("secretsmanager", region_name=REGION_NAME)
        resp = sm.get_secret_value(SecretId=SECRET_NAME)
    except ClientError as e:
        st.error(f"Failed to load secret '{SECRET_NAME}': {e}")
        st.stop()

    if "SecretString" in resp:
        data = json.loads(resp["SecretString"])
    else:
        data = json.loads(base64.b64decode(resp["SecretBinary"]))

    # quick sanity check
    required = [
        "SNOWFLAKE_ACCOUNT","SNOWFLAKE_USER","SNOWFLAKE_ROLE",
        "SNOWFLAKE_WAREHOUSE","SNOWFLAKE_DATABASE","SNOWFLAKE_SCHEMA",
        "PRIVATE_KEY_PEM_B64"
    ]
    missing = [k for k in required if not data.get(k)]
    if missing:
        st.error(f"Missing keys in secret: {missing}")
        st.stop()
    return data

# ---------- Snowflake connection (key-pair) ----------
@st.cache_resource(show_spinner=False)
def get_conn():
    sec = get_secret_dict()
    private_key = base64.b64decode(sec["PRIVATE_KEY_PEM_B64"])
    kwargs = dict(
        account   = sec["SNOWFLAKE_ACCOUNT"],      # e.g. zudcypc-noc91029
        user      = sec["SNOWFLAKE_USER"],         # APP_STREAMLIT
        role      = sec["SNOWFLAKE_ROLE"],
        warehouse = sec["SNOWFLAKE_WAREHOUSE"],
        database  = sec["SNOWFLAKE_DATABASE"],
        schema    = sec["SNOWFLAKE_SCHEMA"],
        private_key = private_key,
        client_session_keep_alive = True,
    )
    if sec.get("PRIVATE_KEY_PASSPHRASE"):
        kwargs["private_key_password"] = sec["PRIVATE_KEY_PASSPHRASE"]
    return snowflake.connector.connect(**kwargs)

# ---------- Query helper ----------
@st.cache_data(ttl=300, show_spinner=False)
def fetch_df(sql: str) -> pd.DataFrame:
    with get_conn() as conn:
        return pd.read_sql(sql, conn)

# ---------- UI ----------
st.title("Snowflake ↔ Streamlit (EC2)")
st.caption("Key-pair auth via AWS Secrets Manager")

# example query: adjust for your table(s)
n = st.slider("Rows", 5, 100, 25, step=5)
sql = f"""
SELECT *
FROM SNACKLASH2.RAW.RSS_ARTICLES
ORDER BY PULLED_AT DESC
LIMIT {int(n)}
"""
df = fetch_df(sql)
st.dataframe(df, use_container_width=True)
# Out:
# 2025-10-01 17:15:23.118 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-01 17:15:23.119 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-01 17:15:23.140
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/joelmiddleton/snow_env/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-10-01 17:15:23.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-01 17:15:23.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-01 17:15:23.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-01 17:15:23.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-01 17:15:23.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-01 17:15:23.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-01 17:15:23.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-01 17:15:23.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-01 17:15:23.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-01 17:15:23.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-01 17:15:23.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-01 17:15:23.145 No runtime found, using MemoryCacheStorageManager
# 2025-10-01 17:15:23.431 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-01 17:15:23.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-01 17:15:23.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-01 17:15:23.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[8], line 76
#      69 n = st.slider("Rows", 5, 100, 25, step=5)
#      70 sql = f"""
#      71 SELECT *
#      72 FROM SNACKLASH2.RAW.RSS_ARTICLES
#      73 ORDER BY PULLED_AT DESC
#      74 LIMIT {int(n)}
#      75 """
# ---> 76 df = fetch_df(sql)
#      77 st.dataframe(df, use_container_width=True)
#
# File ~/snow_env/lib/python3.12/site-packages/streamlit/runtime/caching/cache_utils.py:227, in CachedFunc.__call__(self, *args, **kwargs)
#     224     else:
#     225         spinner_message = f"Running `{name}(...)`."
# --> 227 return self._get_or_create_cached_value(args, kwargs, spinner_message)
#
# File ~/snow_env/lib/python3.12/site-packages/streamlit/runtime/caching/cache_utils.py:269, in CachedFunc._get_or_create_cached_value(self, func_args, func_kwargs, spinner_message)
#     263 spinner_or_no_context = (
#     264     spinner(spinner_message, _cache=True, show_time=self._info.show_time)
#     265     if spinner_message is not None and not is_nested_cache_function
#     266     else contextlib.nullcontext()
#     267 )
#     268 with spinner_or_no_context:
# --> 269     return self._handle_cache_miss(cache, value_key, func_args, func_kwargs)
#
# File ~/snow_env/lib/python3.12/site-packages/streamlit/runtime/caching/cache_utils.py:328, in CachedFunc._handle_cache_miss(self, cache, value_key, func_args, func_kwargs)
#     324 # We acquired the lock before any other thread. Compute the value!
#     325 with self._info.cached_message_replay_ctx.calling_cached_function(
#     326     self._info.func
#     327 ):
# --> 328     computed_value = self._info.func(*func_args, **func_kwargs)
#     330 # We've computed our value, and now we need to write it back to the cache
#     331 # along with any "replay messages" that were generated during value computation.
#     332 messages = self._info.cached_message_replay_ctx._most_recent_messages
#
# Cell In[8], line 61, in fetch_df(sql)
#      59 @st.cache_data(ttl=300, show_spinner=False)
#      60 def fetch_df(sql: str) -> pd.DataFrame:
# ---> 61     with get_conn() as conn:
#      62         return pd.read_sql(sql, conn)
#
# File ~/snow_env/lib/python3.12/site-packages/streamlit/runtime/caching/cache_utils.py:227, in CachedFunc.__call__(self, *args, **kwargs)
#     224     else:
#     225         spinner_message = f"Running `{name}(...)`."
# --> 227 return self._get_or_create_cached_value(args, kwargs, spinner_message)
#
# File ~/snow_env/lib/python3.12/site-packages/streamlit/runtime/caching/cache_utils.py:269, in CachedFunc._get_or_create_cached_value(self, func_args, func_kwargs, spinner_message)
#     263 spinner_or_no_context = (
#     264     spinner(spinner_message, _cache=True, show_time=self._info.show_time)
#     265     if spinner_message is not None and not is_nested_cache_function
#     266     else contextlib.nullcontext()
#     267 )
#     268 with spinner_or_no_context:
# --> 269     return self._handle_cache_miss(cache, value_key, func_args, func_kwargs)
#
# File ~/snow_env/lib/python3.12/site-packages/streamlit/runtime/caching/cache_utils.py:328, in CachedFunc._handle_cache_miss(self, cache, value_key, func_args, func_kwargs)
#     324 # We acquired the lock before any other thread. Compute the value!
#     325 with self._info.cached_message_replay_ctx.calling_cached_function(
#     326     self._info.func
#     327 ):
# --> 328     computed_value = self._info.func(*func_args, **func_kwargs)
#     330 # We've computed our value, and now we need to write it back to the cache
#     331 # along with any "replay messages" that were generated during value computation.
#     332 messages = self._info.cached_message_replay_ctx._most_recent_messages
#
# Cell In[8], line 42, in get_conn()
#      40 @st.cache_resource(show_spinner=False)
#      41 def get_conn():
# ---> 42     sec = get_secret_dict()
#      43     private_key = base64.b64decode(sec["PRIVATE_KEY_PEM_B64"])
#      44     kwargs = dict(
#      45         account   = sec["SNOWFLAKE_ACCOUNT"],      # e.g. zudcypc-noc91029
#      46         user      = sec["SNOWFLAKE_USER"],         # APP_STREAMLIT
#    (...)
#      52         client_session_keep_alive = True,
#      53     )
#
# File ~/snow_env/lib/python3.12/site-packages/streamlit/runtime/caching/cache_utils.py:227, in CachedFunc.__call__(self, *args, **kwargs)
#     224     else:
#     225         spinner_message = f"Running `{name}(...)`."
# --> 227 return self._get_or_create_cached_value(args, kwargs, spinner_message)
#
# File ~/snow_env/lib/python3.12/site-packages/streamlit/runtime/caching/cache_utils.py:269, in CachedFunc._get_or_create_cached_value(self, func_args, func_kwargs, spinner_message)
#     263 spinner_or_no_context = (
#     264     spinner(spinner_message, _cache=True, show_time=self._info.show_time)
#     265     if spinner_message is not None and not is_nested_cache_function
#     266     else contextlib.nullcontext()
#     267 )
#     268 with spinner_or_no_context:
# --> 269     return self._handle_cache_miss(cache, value_key, func_args, func_kwargs)
#
# File ~/snow_env/lib/python3.12/site-packages/streamlit/runtime/caching/cache_utils.py:328, in CachedFunc._handle_cache_miss(self, cache, value_key, func_args, func_kwargs)
#     324 # We acquired the lock before any other thread. Compute the value!
#     325 with self._info.cached_message_replay_ctx.calling_cached_function(
#     326     self._info.func
#     327 ):
# --> 328     computed_value = self._info.func(*func_args, **func_kwargs)
#     330 # We've computed our value, and now we need to write it back to the cache
#     331 # along with any "replay messages" that were generated during value computation.
#     332 messages = self._info.cached_message_replay_ctx._most_recent_messages
#
# Cell In[8], line 22, in get_secret_dict()
#      19     st.error(f"Failed to load secret '{SECRET_NAME}': {e}")
#      20     st.stop()
# ---> 22 if "SecretString" in resp:
#      23     data = json.loads(resp["SecretString"])
#      24 else:
#
# UnboundLocalError: cannot access local variable 'resp' where it is not associated with a value
